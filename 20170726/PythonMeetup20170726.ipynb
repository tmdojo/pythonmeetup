# %% [markdown]
# # Pythonの実行方法

# %% [markdown]
# * Command line
# * .py file with text editor
# * .py file with IDE
# * Jupyter Notebook

# %% [markdown]
# # First python code

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
"ABC"
# Out:
# 'ABC'

# %%
1+2
# Out:
# 3

# %%
 1/3
# Out:
# 0.3333333333333333

# %%
1.0/3
# Out:
# 0.3333333333333333

# %%
(1.0/3)*3
# Out:
# 1.0

# %%
2**3
# Out:
# 8

# %%
11%4
# Out:
# 3

# %% [markdown]
# # List of Differences between Python 2 and 3
#
# http://sebastianraschka.com/Articles/2014_python_2_3_key_diff.html

# %% [markdown]
# # Complete Python Bootcamp video lecture
#
# Course on Udemy
# https://www.udemy.com/complete-python-bootcamp/learn/v4/overview
#
# View course note on nbViewer
# http://nbviewer.jupyter.org/github/jmportilla/Complete-Python-Bootcamp/tree/master/
#
# or Download course note
# https://github.com/jmportilla/Complete-Python-Bootcamp/archive/master.zip

# %% [markdown]
# # Making plots

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
logname = "mydata"
logfile = logname + ".csv"

# %% [markdown]
# ## normal way to read csv file

# %%
with open(logfile) as f:
    line = f.readline()
    print(line)
# Out:
# 1,27.875,86.8443309686,0,86.7375,0.1,0.00683096855439

# %%
line
# Out:
# '1,27.875,86.8443309686,0,86.7375,0.1,0.00683096855439\n'

# %%
line.strip()
# Out:
# '1,27.875,86.8443309686,0,86.7375,0.1,0.00683096855439'

# %%
line.strip().split(',')
# Out:
# ['1', '27.875', '86.8443309686', '0', '86.7375', '0.1', '0.00683096855439']

# %%
data = []
for item in line.strip().split(','):
    data.append(float(item))
print(data)
# Out:
# [1.0, 27.875, 86.8443309686, 0.0, 86.7375, 0.1, 0.00683096855439]

# %%
[float(item) for item in line.strip().split(',')]
# Out:
# [1.0, 27.875, 86.8443309686, 0.0, 86.7375, 0.1, 0.00683096855439]

# %% [markdown]
# continue on...

# %% [markdown]
# ## Easy way to read csv as numpy array

# %%
time_t, temperature, pwr, tempe_bottom, P, I, D = np.loadtxt(logfile, delimiter=',', unpack=True)

# %%
time_t
# Out:
# array([  1.00000000e+00,   1.30000000e+01,   2.60000000e+01,
#          3.90000000e+01,   5.10000000e+01,   6.40000000e+01,
#          7.70000000e+01,   9.00000000e+01,   1.03000000e+02,
#          1.15000000e+02,   1.28000000e+02,   1.41000000e+02,
#          1.53000000e+02,   1.66000000e+02,   1.79000000e+02,
#          1.91000000e+02,   2.04000000e+02,   2.17000000e+02,
#          2.30000000e+02,   2.43000000e+02,   2.55000000e+02,
#          2.68000000e+02,   2.81000000e+02,   2.94000000e+02,
#          3.06000000e+02,   3.19000000e+02,   3.32000000e+02,
#          3.45000000e+02,   3.57000000e+02,   3.70000000e+02,
#          3.83000000e+02,   3.95000000e+02,   4.08000000e+02,
#          4.21000000e+02,   4.34000000e+02,   4.47000000e+02,
#          4.59000000e+02,   4.72000000e+02,   4.85000000e+02,
#          4.98000000e+02,   5.10000000e+02,   5.23000000e+02,
#          5.36000000e+02,   5.48000000e+02,   5.61000000e+02,
# ...

# %%
len(time_t)
# Out:
# 459

# %%
temperature
# Out:
# array([ 27.875,  27.875,  27.875,  27.875,  27.875,  27.875,  27.875,
#         27.875,  27.875,  27.875,  27.875,  27.875,  27.875,  27.875,
#         27.875,  27.875,  27.812,  27.812,  27.875,  29.187,  30.437,
#         33.062,  35.75 ,  38.062,  40.562,  43.687,  45.562,  47.75 ,
#         50.125,  52.375,  55.437,  57.562,  59.937,  62.562,  64.312,
#         65.312,  65.562,  65.562,  65.5  ,  65.062,  62.937,  61.312,
#         60.375,  59.5  ,  58.75 ,  59.625,  62.125,  64.   ,  64.875,
#         65.437,  65.187,  64.875,  64.562,  64.187,  63.812,  63.437,
#         63.062,  62.75 ,  62.437,  62.125,  61.875,  61.625,  61.375,
#         61.125,  60.937,  60.687,  60.5  ,  60.312,  60.125,  59.937,
#         59.75 ,  59.687,  60.5  ,  62.   ,  63.312,  63.875,  63.687,
#         63.5  ,  63.312,  63.125,  63.   ,  62.812,  62.687,  62.5  ,
#         62.375,  62.25 ,  62.125,  62.   ,  61.875,  61.75 ,  61.625,
# ...

# %%
plt.plot(time_t, temperature)

# %%
fig = plt.figure(facecolor='white')
ax = fig.add_subplot('211')
ax.plot(time_t/60, temperature, label='temperature')
#ax.set_xlabel('Elapsed time (min)')
ax.set_ylabel('Temperature (degrees C)')
ax.set_title('Pot')
ax.grid('on')
ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1))

ax2 = fig.add_subplot('212')
ax2.plot(time_t/60, pwr, label='power')
ax2.plot(time_t/60, P, label='P')
ax2.plot(time_t/60, I, label='I')
ax2.plot(time_t/60, D, label='D')
ax2.set_xlabel('Elapsed time (min)')
ax2.set_ylabel('Control')
#ax2.set_title('Pot')
ax2.grid('on')
ax2.legend(loc='upper left', bbox_to_anchor=(1.0, 1))

plt.tight_layout()

# %%
plt.hist(temperature)
# Out:
# (array([  21.,    1.,    2.,    1.,    2.,    2.,    1.,    2.,  373.,   54.]),
#  array([ 27.812,  31.587,  35.362,  39.137,  42.912,  46.687,  50.462,
#          54.237,  58.012,  61.787,  65.562]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(temperature, bins=50);

# save plot
plt.savefig(logname + "_hist.png")

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

# %%
startx = 40
stopx = 50

fig, ax = plt.subplots()
ax.errorbar(time_t[startx:stopx]/60, temperature[startx:stopx], yerr=1)
# Out:
# <Container object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.scatter(temperature, pwr)
ax.set_xlabel('temperature')
ax.set_ylabel('power')

# %% [markdown]
# ## Correration analysis example

# %%
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# # get file names in directory

# %%
import glob
import os

# %%
csv_list = glob.glob("*.csv")
csv_list
# Out:
# ['mydata.csv']

# %%
filename, file_extension = os.path.splitext(csv_list[0])
print(filename)
print(file_extension)
# Out:
# mydata
# .csv
